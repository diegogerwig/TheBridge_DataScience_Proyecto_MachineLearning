# %% [markdown]
# https://www.comet.com/

# %%
# !pip install comet_ml
# !pip install python-dotenv
# Out:
# Requirement already satisfied: comet_ml in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (3.45.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (3.1.1)
# Requirement already satisfied: everett[ini]<3.2.0,>=1.0.1 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (3.1.0)
# Requirement already satisfied: python-box<7.0.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (6.1.0)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (4.23.0)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (2.2.2)
# Requirement already satisfied: semantic-version>=2.8.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (2.10.0)
# Requirement already satisfied: rich>=13.3.2 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (13.8.0)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (0.22.1)
# Requirement already satisfied: simplejson in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (3.19.3)
# Requirement already satisfied: requests>=2.18.4 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (1.0.0)
# Requirement already satisfied: psutil>=5.6.3 in c:\users\usuario\appdata\roaming\python\python310\site-packages (from comet_ml) (6.0.0)
# Requirement already satisfied: wrapt>=1.11.2 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (1.16.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from comet_ml) (2.13.0)
# Requirement already satisfied: configobj in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from everett[ini]<3.2.0,>=1.0.1->comet_ml) (5.0.8)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.20.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->comet_ml) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->comet_ml) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->comet_ml) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from rich>=13.3.2->comet_ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\usuario\appdata\roaming\python\python310\site-packages (from rich>=13.3.2->comet_ml) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)
# Requirement already satisfied: six in c:\users\usuario\appdata\roaming\python\python310\site-packages (from configobj->everett[ini]<3.2.0,>=1.0.1->comet_ml) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (1.0.1)
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
from comet_ml import Experiment
          
experiment = Experiment(
  api_key=os.environ.get("COMET_API_KEY"),  # 
  project_name="general",
  workspace="diegogerwig"
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/diegogerwig/general/e012eec9ecf9480e8af4c6ba9efd4b6f

# %%
experiment.end()
# Out:
# COMET INFO: The process of logging environment details (conda environment, git patch) is underway. Please be patient as this may take some time.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : net_north_4001
# COMET INFO:     url                   : https://www.comet.com/diegogerwig/general/e012eec9ecf9480e8af4c6ba9efd4b6f
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30.01 MB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: Still uploading 1 file(s), remaining 1.03 MB/1.63 MB
